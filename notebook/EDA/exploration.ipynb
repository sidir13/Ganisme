# %% [markdown]
# # Introduction
# Préparation et EDA des données

# %% [markdown]
# ## SPLITTING

# %%
import os, random, shutil, pathlib
random.seed(42)

def split_folder(src, train_dst, test_dst, test_ratio=0.1):
    os.makedirs(train_dst, exist_ok=True); os.makedirs(test_dst, exist_ok=True)
    files = [f for f in os.listdir(src) if f.lower().endswith(('.jpg','.png','.jpeg'))]
    random.shuffle(files)
    k = int(len(files)*test_ratio)
    test, train = files[:k], files[k:]
    for f in train: shutil.copy2(os.path.join(src,f), os.path.join(train_dst,f))
    for f in test:  shutil.copy2(os.path.join(src,f), os.path.join(test_dst,f))

split_folder("../../data/processed/img_celeb", "../../data/processed/img_celeb/trainA", "../../data/processed/img_celeb/testA")
split_folder("../../data/processed/paint_portrait", "../../data/processed/paint_portrait/trainB", "../../data/processed/paint_portrait/testB")

# %%
import os, PIL.Image as Image, statistics as st
def sizes(folder):
    wh=[]; 
    for f in os.listdir(folder):
        if f.lower().endswith(('.jpg','.png','.jpeg')):
            w,h = Image.open(os.path.join(folder,f)).size; wh.append((w,h))
    return wh

for d in ["trainA","trainB","testA","testB"]:
    wh = sizes(f"../../data/portraits/{d}")
    print(d, len(wh), "images — médiane:", (st.median([w for w,h in wh]), st.median([h for w,h in wh])))
